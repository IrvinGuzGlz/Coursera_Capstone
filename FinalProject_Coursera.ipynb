# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', False)
pd.set_option('display.max_rows', False)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

 #import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes 
import folium # map rendering library

import lxml
print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# # 1st Assigment

# %%
urlwiki='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
toronto=pd.read_html(urlwiki)

# %% [markdown]
# ### Eliminate not assgined Boroughs

# %%
df_toronto= pd.DataFrame(toronto[0])
df_torontoW = df_toronto.loc[df_toronto['Borough']!='Not assigned']
#df_toronto.drop(df_toronto['Borough']=='Not assigned',axis=0,)

# %%
df_torontoW.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
# 5      M6A        North York  Lawrence Heights
# 6      M6A        North York    Lawrence Manor

# %% [markdown]
# ### Merge same postcode

# %%
post_counts=df_torontoW['Postcode'].value_counts()
post_counts[0:5]
# Out:
# M8Y    8
# M9V    8
# M5V    7
# M8Z    5
# M4V    5
# Name: Postcode, dtype: int64

# %%
df_grouped=df_torontoW.groupby(['Postcode','Borough']).agg(lambda x: ', '.join(x))

# %%
df_grouped.reset_index(level=['Postcode','Borough'], inplace=True)

# %%
for n in range(df_grouped.shape[0]):
    if df_grouped.loc[n,'Neighbourhood'] == 'Not assigned':
        df_grouped.loc[n,'Neighbourhood'] = df_grouped.loc[n,'Borough']

# %% [markdown]
# ### With the past code we obtain the dataframe as it was required for the activity

# %%
df_grouped
# Out:
#     Postcode      Borough                                      Neighbourhood
# 0        M1B  Scarborough                                     Rouge, Malvern
# 1        M1C  Scarborough             Highland Creek, Rouge Hill, Port Union
# 2        M1E  Scarborough                  Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                             Woburn
# 4        M1H  Scarborough                                          Cedarbrae
# 5        M1J  Scarborough                                Scarborough Village
# 6        M1K  Scarborough        East Birchmount Park, Ionview, Kennedy Park
# 7        M1L  Scarborough                    Clairlea, Golden Mile, Oakridge
# 8        M1M  Scarborough    Cliffcrest, Cliffside, Scarborough Village West
# ..       ...          ...                                                ...
# 94       M9B    Etobicoke  Cloverdale, Islington, Martin Grove, Princess ...
# ...

# %%
df_grouped.shape
# Out:
# (103, 3)

# %% [markdown]
# # 2nd Assigment

# %%
Cords=pd.read_csv('Geospatial_Coordinates.csv')
Cords.columns.values[0]='Postcode'

# %%
Cords
# Out:
#     Postcode   Latitude  Longitude
# 0        M1B  43.806686 -79.194353
# 1        M1C  43.784535 -79.160497
# 2        M1E  43.763573 -79.188711
# 3        M1G  43.770992 -79.216917
# 4        M1H  43.773136 -79.239476
# 5        M1J  43.744734 -79.239476
# 6        M1K  43.727929 -79.262029
# 7        M1L  43.711112 -79.284577
# 8        M1M  43.716316 -79.239476
# ..       ...        ...        ...
# 94       M9B  43.650943 -79.554724
# 95       M9C  43.643515 -79.577201
# 96       M9L  43.756303 -79.565963
# 97       M9M  43.724766 -79.532242
# 98       M9N  43.706876 -79.518188
# 99       M9P  43.696319 -79.532242
# 100      M9R  43.688905 -79.554724
# 101      M9V  43.739416 -79.588437
# 102      M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %%
df_Cord=pd.merge(df_grouped,Cords, on='Postcode')

# %%
df_Cord
# Out:
#     Postcode      Borough  ...   Latitude  Longitude
# 0        M1B  Scarborough  ...  43.806686 -79.194353
# 1        M1C  Scarborough  ...  43.784535 -79.160497
# 2        M1E  Scarborough  ...  43.763573 -79.188711
# 3        M1G  Scarborough  ...  43.770992 -79.216917
# 4        M1H  Scarborough  ...  43.773136 -79.239476
# 5        M1J  Scarborough  ...  43.744734 -79.239476
# 6        M1K  Scarborough  ...  43.727929 -79.262029
# 7        M1L  Scarborough  ...  43.711112 -79.284577
# 8        M1M  Scarborough  ...  43.716316 -79.239476
# ..       ...          ...  ...        ...        ...
# 94       M9B    Etobicoke  ...  43.650943 -79.554724
# 95       M9C    Etobicoke  ...  43.643515 -79.577201
# 96       M9L   North York  ...  43.756303 -79.565963
# 97       M9M   North York  ...  43.724766 -79.532242
# 98       M9N         York  ...  43.706876 -79.518188
# 99       M9P    Etobicoke  ...  43.696319 -79.532242
# 100      M9R    Etobicoke  ...  43.688905 -79.554724
# ...

# %% [markdown]
# # 3rd Assigment

# %%
address = 'Toronto, CA'

geolocator = Nominatim(user_agent="t_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

# %%
print(latitude)
print(longitude)
#print('The geograpical coordinate of New York City are {}, {}.'.format(latitude, longitude)
# Out:
# 43.653963
# -79.387207

# %%
# create map of New York using latitude and longitude values
map_Toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df_Cord['Latitude'], df_Cord['Longitude'], df_Cord['Borough'], df_Cord['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Toronto)  
    
map_Toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## I am going t be using the complete set of PostalCodes to make the segmentation and clustering.

# %% [markdown]
# ## Now I will explore the postal code M5S because there is found the neighborhood of the University of Toronto in Downtonw of Toronto .

# %%
df_Cord.loc[df_Cord['Neighbourhood']=='Harbord, University of Toronto']
# Out:
#    Postcode           Borough  ...   Latitude  Longitude
# 66      M5S  Downtown Toronto  ...  43.662696 -79.400049
#
# [1 rows x 5 columns]

# %%
UT_latitude = df_Cord.loc[66, 'Latitude'] # neighborhood latitude value
UT_longitude = df_Cord.loc[66, 'Longitude'] # neighborhood longitude value

UT_name = df_Cord.loc[66, 'Neighbourhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(UT_name, 
                                                               UT_latitude, 
                                                               UT_longitude))
# Out:
# Latitude and longitude values of Harbord, University of Toronto are 43.6626956, -79.4000493.

# %% [markdown]
# #### As in the problem of NY I get the top 100 venues that are in University of Toronto zone within a radius of 500 meters.

# %%
CLIENT_ID = 'TXOUOT3UGXOZAQMIUNEJ1OES5C3ZOHZQUDL5E1BA5XE4GPAN' # your Foursquare ID
CLIENT_SECRET = 'JM4YAMR1YJKW1WBQHOO2I1NTJVOR515MI33DTJNNRUDB3SGN' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT=100
radius=500
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    UT_latitude, 
    UT_longitude, 
    radius, 
    LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=TXOUOT3UGXOZAQMIUNEJ1OES5C3ZOHZQUDL5E1BA5XE4GPAN&client_secret=JM4YAMR1YJKW1WBQHOO2I1NTJVOR515MI33DTJNNRUDB3SGN&v=20180605&ll=43.6626956,-79.4000493&radius=500&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5de9924c660a9f4dabafd7f6'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'University of Toronto',
#   'headerFullLocation': 'University of Toronto, Toronto',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 38,
#   'suggestedBounds': {'ne': {'lat': 43.6671956045, 'lng': -79.39384042790832},
#    'sw': {'lat': 43.6581955955, 'lng': -79.4062581720917}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5362c366498e602fbe1db395',
#        'name': 'Yasu',
#        'location': {'address': '81 Harbord St.',
#         'lat': 43.66283719650635,
#         'lng': -79.40321739973975,
# ...

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
nearby_venues = json_normalize(venues) # flatten JSON
# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]
#filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)
# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]
nearby_venues.head(8)
# Out:
#                                name           categories        lat        lng
# 0                              Yasu  Japanese Restaurant  43.662837 -79.403217
# 1               The Dessert Kitchen         Dessert Shop  43.662823 -79.402746
# 2                       Piano Piano   Italian Restaurant  43.662949 -79.402898
# 3                              Rasa           Restaurant  43.662757 -79.403988
# 4                  Almond Butterfly               Bakery  43.662836 -79.403365
# 5  Her Father's Cider Bar + Kitchen             Beer Bar  43.662448 -79.404703
# 6                   Athletic Centre          College Gym  43.662487 -79.400657
# 7                       Cafe Cancan    French Restaurant  43.662735 -79.403447

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 38 venues were returned by Foursquare.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    iCount=0
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])
        
        iCount = iCount+1

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Postcode', 
                  'Postcode Latitude', 
                  'Postcode Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
            
    
    return(nearby_venues,iCount)

# %%
[Toronto_venues,Count] = getNearbyVenues(names=df_Cord['Postcode'],
                                   latitudes=df_Cord['Latitude'],
                                   longitudes=df_Cord['Longitude']
                                  )
print(Count)
# Out:
# M1B
# M1C
# M1E
# M1G
# M1H
# M1J
# M1K
# M1L
# M1M
# M1N
# M1P
# M1R
# M1S
# M1T
# M1V
# M1W
# M1X
# M2H
# M2J
# M2K
# M2L
# M2M
# M2N
# M2P
# M2R
# M3A
# M3B
# M3C
# M3H
# M3J
# M3K
# M3L
# M3M
# M3N
# M4A
# M4B
# M4C
# M4E
# M4G
# M4H
# M4J
# M4K
# M4L
# M4M
# M4N
# M4P
# M4R
# M4S
# M4T
# M4V
# M4W
# M4X
# M4Y
# M5A
# M5B
# M5C
# M5E
# M5G
# M5H
# M5J
# M5K
# M5L
# M5M
# M5N
# M5P
# M5R
# M5S
# M5T
# M5V
# M5W
# M5X
# M6A
# M6B
# M6C
# M6E
# M6G
# M6H
# M6J
# M6K
# M6L
# M6M
# M6N
# M6P
# M6R
# M6S
# M7A
# M7R
# M7Y
# M8V
# M8W
# M8X
# M8Y
# M8Z
# M9A
# M9B
# M9C
# M9L
# M9M
# M9N
# M9P
# M9R
# M9V
# M9W
# 103

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-92-9bc0cb2ed6de> in <module>
# ----> 1 name
#
# NameError: name 'name' is not defined

# %%
print(Toronto_venues.shape)
Toronto_venues.head()
# Out:
# (2235, 7)
#   Postcode  Postcode Latitude  ...  Venue Longitude        Venue Category
# 0      M1B          43.806686  ...       -79.199056  Fast Food Restaurant
# 1      M1C          43.784535  ...       -79.163085                   Bar
# 2      M1E          43.763573  ...       -79.189914           Pizza Place
# 3      M1E          43.763573  ...       -79.191537     Electronics Store
# 4      M1E          43.763573  ...       -79.191000                   Spa
#
# [5 rows x 7 columns]

# %%
Toronto_venues.groupby('Postcode').count()
# Out:
#           Postcode Latitude  ...  Venue Category
# Postcode                     ...
# M1B                       1  ...               1
# M1C                       1  ...               1
# M1E                       8  ...               8
# M1G                       3  ...               3
# M1H                       8  ...               8
# M1J                       1  ...               1
# M1K                       5  ...               5
# M1L                      10  ...              10
# M1M                       2  ...               2
# ...                     ...  ...             ...
# M9B                       1  ...               1
# M9C                       7  ...               7
# M9L                       3  ...               3
# M9M                       1  ...               1
# M9N                       3  ...               3
# M9P                       8  ...               8
# M9R                       4  ...               4
# ...

# %%
print('There are {} uniques categories.'.format(len(Toronto_venues['Venue Category'].unique())))
# Out:
# There are 278 uniques categories.

# %% [markdown]
# ## Analyzing each Postal code

# %%
# one hot encoding
Toronto_onehot = pd.get_dummies(Toronto_venues[['Venue Category']], prefix="", prefix_sep="")
# add Postalcode column back to dataframe
Toronto_onehot['Postcode'] = Toronto_venues['Postcode']
# move neighborhood column to the first column
fixed_columns = [Toronto_onehot.columns[-1]] + list(Toronto_onehot.columns[:-1])
Toronto_onehot = Toronto_onehot[fixed_columns]
Toronto_onehot.head()
# Out:
#   Postcode  Accessories Store  ...  Women's Store  Yoga Studio
# 0      M1B                  0  ...              0            0
# 1      M1C                  0  ...              0            0
# 2      M1E                  0  ...              0            0
# 3      M1E                  0  ...              0            0
# 4      M1E                  0  ...              0            0
#
# [5 rows x 279 columns]

# %%
Toronto_onehot.shape
# Out:
# (2235, 279)

# %%
Toronto_grouped = Toronto_onehot.groupby('Postcode').mean().reset_index()
Toronto_grouped
# Out:
#    Postcode  Accessories Store  ...  Women's Store  Yoga Studio
# 0       M1B                0.0  ...            0.0          0.0
# 1       M1C                0.0  ...            0.0          0.0
# 2       M1E                0.0  ...            0.0          0.0
# 3       M1G                0.0  ...            0.0          0.0
# 4       M1H                0.0  ...            0.0          0.0
# 5       M1J                0.0  ...            0.0          0.0
# 6       M1K                0.0  ...            0.0          0.0
# 7       M1L                0.0  ...            0.0          0.0
# 8       M1M                0.0  ...            0.0          0.0
# ..      ...                ...  ...            ...          ...
# 91      M9B                0.0  ...            0.0          0.0
# 92      M9C                0.0  ...            0.0          0.0
# 93      M9L                0.0  ...            0.0          0.0
# 94      M9M                0.0  ...            0.0          0.0
# ...

# %%
Toronto_grouped.shape
# Out:
# (100, 279)

# %%
num_top_venues = 5

for hood in Toronto_grouped['Postcode']:
    print("----"+hood+"----")
    temp = Toronto_grouped[Toronto_grouped['Postcode'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----M1B----
#                   venue  freq
# 0  Fast Food Restaurant   1.0
# 1    Miscellaneous Shop   0.0
# 2         Movie Theater   0.0
# 3                 Motel   0.0
# 4   Monument / Landmark   0.0
#
#
# ----M1C----
#                venue  freq
# 0                Bar   1.0
# 1  Accessories Store   0.0
# 2  Mobile Phone Shop   0.0
# 3      Movie Theater   0.0
# 4              Motel   0.0
#
#
# ----M1E----
#                  venue  freq
# 0         Intersection  0.12
# 1  Rental Car Location  0.12
# 2                  Spa  0.12
# 3       Breakfast Spot  0.12
# 4   Mexican Restaurant  0.12
#
#
# ----M1G----
#                venue  freq
# 0        Coffee Shop  0.67
# 1  Korean Restaurant  0.33
# 2  Accessories Store  0.00
# 3             Museum  0.00
# 4      Movie Theater  0.00
#
#
# ----M1H----
#                   venue  freq
# 0           Gas Station  0.12
# 1                  Bank  0.12
# 2  Caribbean Restaurant  0.12
# 3       Thai Restaurant  0.12
# ...

# %% [markdown]
# ### Les put it on a Dataframe

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Postcode']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
Postcode_venues_sorted = pd.DataFrame(columns=columns)
Postcode_venues_sorted['Postcode'] = Toronto_grouped['Postcode']

for ind in np.arange(Toronto_grouped.shape[0]):
    Postcode_venues_sorted.iloc[ind, 1:] = return_most_common_venues(Toronto_grouped.iloc[ind, :], num_top_venues)
Postcode_venues_sorted.head()
# Out:
#   Postcode 1st Most Common Venue  ... 9th Most Common Venue 10th Most Common Venue
# 0      M1B  Fast Food Restaurant  ...            Donut Shop    Dumpling Restaurant
# 1      M1C                   Bar  ...   Dumpling Restaurant           Dessert Shop
# 2      M1E   Rental Car Location  ...    Dim Sum Restaurant                  Diner
# 3      M1G           Coffee Shop  ...      Doner Restaurant             Donut Shop
# 4      M1H      Hakka Restaurant  ...             Drugstore             Donut Shop
#
# [5 rows x 11 columns]

# %% [markdown]
# ## Cluster Neighborhoods

# %%
# set number of clusters
kclusters = 5

Toronto_grouped_clustering = Toronto_grouped.drop('Postcode', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(Toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 3, 3, 3, 3, 3, 3, 3, 3, 3])

# %%
# add clustering labels
Postcode_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

Toronto_merged = df_Cord

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
Toronto_merged = Toronto_merged.join(Postcode_venues_sorted.set_index('Postcode'), on='Postcode')

Toronto_merged.head() # check the last columns!
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-4ca595802fab> in <module>
#       1 # add clustering labels
# ----> 2 Postcode_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
#       3
#       4 Toronto_merged = df_Cord
#       5
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3589         self._ensure_valid_index(value)
#    3590         value = self._sanitize_column(column, value, broadcast=False)
# -> 3591         self._data.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3592
#    3593     def assign(self, **kwargs):
#
# C:\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1171         if not allow_duplicates and item in self.items:
# ...

# %%
Toronto_merged.shape
Toronto_merged['Cluster Labels'].fillna(0,inplace=True)
# Out:
# (103, 16)

# %%
# Out:
# dtype('float64')

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(Toronto_merged['Latitude'], Toronto_merged['Longitude'], Toronto_merged['Postcode'], Toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster-1)],
        fill=True,
        fill_color=rainbow[int(cluster-1)],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Analyzing the Clusters

# %% [markdown]
# ## Cluster 1

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 0, Toronto_merged.columns[[1] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#          Borough  Cluster Labels  ... 9th Most Common Venue 10th Most Common Venue
# 0    Scarborough             0.0  ...            Donut Shop    Dumpling Restaurant
# 16   Scarborough             0.0  ...                   NaN                    NaN
# 17    North York             0.0  ...        Discount Store       Doner Restaurant
# 21    North York             0.0  ...                   NaN                    NaN
# 93  Queen's Park             0.0  ...                   NaN                    NaN
#
# [5 rows x 12 columns]

# %% [markdown]
# ## Cluster 2

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 1, Toronto_merged.columns[[1] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#              Borough  ...  10th Most Common Venue
# 14       Scarborough  ...              Donut Shop
# 23        North York  ...              Donut Shop
# 25        North York  ...               Drugstore
# 30        North York  ...              Donut Shop
# 40         East York  ...              Donut Shop
# 50  Downtown Toronto  ...                 Dog Run
# 74              York  ...     Empanada Restaurant
# 79        North York  ...              Donut Shop
# 90         Etobicoke  ...            Dance Studio
# 98              York  ...              Donut Shop
#
# [10 rows x 12 columns]

# %% [markdown]
# ## Cluster 3

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 2, Toronto_merged.columns[[1] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#        Borough  Cluster Labels  ... 9th Most Common Venue 10th Most Common Venue
# 32  North York             2.0  ...            Donut Shop              Drugstore
# 91   Etobicoke             2.0  ...            Donut Shop              Drugstore
# 97  North York             2.0  ...   Dumpling Restaurant           Dessert Shop
#
# [3 rows x 12 columns]

# %% [markdown]
# ## Cluster 4

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 3, Toronto_merged.columns[[1] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#          Borough  ...       10th Most Common Venue
# 1    Scarborough  ...                 Dessert Shop
# 2    Scarborough  ...                        Diner
# 3    Scarborough  ...                   Donut Shop
# 4    Scarborough  ...                   Donut Shop
# 5    Scarborough  ...                    Drugstore
# 6    Scarborough  ...             Doner Restaurant
# 7    Scarborough  ...        General Entertainment
# 8    Scarborough  ...                  Yoga Studio
# 9    Scarborough  ...            Electronics Store
# ..           ...  ...                          ...
# 89     Etobicoke  ...                Deli / Bodega
# 92     Etobicoke  ...       Thrift / Vintage Store
# 94     Etobicoke  ...  Eastern European Restaurant
# 95     Etobicoke  ...                        Diner
# 96    North York  ...             Doner Restaurant
# 99     Etobicoke  ...                      Dog Run
# 100    Etobicoke  ...                      Dog Run
# ...

# %% [markdown]
# ## Cluster 5

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 4, Toronto_merged.columns[[1] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#        Borough  Cluster Labels  ... 9th Most Common Venue 10th Most Common Venue
# 20  North York             4.0  ...            Donut Shop    Dumpling Restaurant
#
# [1 rows x 12 columns]
